# %% [markdown]
# <a href="https://colab.research.google.com/github/majickdave/geolocation/blob/main/Geolocation_feature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Explore Dataset 👇
# https://www.kaggle.com/datasets/camnugent/california-housing-prices

# %%
# direct download
# !wget -O /content/archive.zip 'https://github.com/majickdave/geolocation/raw/main/archive.zip'
# Out:
# --2023-09-03 17:55:58--  https://github.com/majickdave/geolocation/raw/main/archive.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/majickdave/geolocation/main/archive.zip [following]
# --2023-09-03 17:55:58--  https://raw.githubusercontent.com/majickdave/geolocation/main/archive.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 409382 (400K) [application/zip]
# Saving to: ‘/content/archive.zip’
#
# /content/archive.zi 100%[===================>] 399.79K  --.-KB/s    in 0.007s
#
# 2023-09-03 17:55:59 (56.9 MB/s) - ‘/content/archive.zip’ saved [409382/409382]

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/archive.zip")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
# ...

# %% [markdown]
# # Choose coords for an east and a west boundary as corners of a rectangle 🗺
#
# create custom map  https://www.google.com/maps/d/

# %%
# lat, lon
WEST = (32.83157, -117.22127)
EAST = (32.77472, -117.16325)

# Write a functiom for location within bounds of east and west
def locate_me(lat, lon):
    w = WEST
    e = EAST
    if lat < w[0] and lon > w[1] and lat > e[0] and lon < e[1]:
        return True
    else:
        return False

# %% [markdown]
# # Create new feature

# %%
# use vectorize to apply function to different columns
df['clairemont'] = np.vectorize(locate_me)(df['latitude'], df['longitude'])

# %% [markdown]
# # Find all rows within the bounaries specified

# %%
df[df['clairemont']==True]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14409    -117.22     32.78                22.0       2020.0           466.0
# 14419    -117.21     32.80                19.0        786.0           282.0
# 14420    -117.22     32.80                23.0       1906.0           525.0
# 14424    -117.22     32.81                21.0       1703.0           335.0
# 14559    -117.22     32.83                34.0       2936.0           597.0
# ...          ...       ...                 ...          ...             ...
# 14640    -117.20     32.79                31.0       3417.0           533.0
# 14641    -117.20     32.79                29.0       1213.0             NaN
# 14642    -117.20     32.79                34.0        757.0           212.0
# 14643    -117.19     32.78                34.0       4108.0           664.0
# 14644    -117.20     32.78                38.0       2662.0           498.0
#
# ...
